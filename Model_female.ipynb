# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
sns.set_palette('magma')

# %%
df= pd.read_csv("dataset_ward_level_cleaned.csv")
df.head()
# Out:
#    Id  Population_2011_Census Ward_Code               Ward_Name District_Code  \
# 0   0                   11201    00ANGQ                    Town          00AN
# 1   1                   11518    00ANGA                 Addison          00AN
# 2   2                   10800    00ADGN  Falconwood and Welling          00AD
# 3   3                   12321    00BEGH            East Dulwich          00BE
# 4   4                   12609    00BCFZ             Barkingside          00BC
#
#                  District  Crime_Rate  Open_Space  hh_Social_Rented  \
# 0  Hammersmith and Fulham       117.7         0.0              23.7
# 1  Hammersmith and Fulham       114.0         0.3              24.9
# 2                  Bexley        44.2         0.7               1.1
# 3               Southwark        65.3         0.7              20.3
# 4               Redbridge        64.3         1.3               4.7
#
#    Job_Seekers  ...  General_Fertility_Rate  Male_Life_Expectancy  \
# ...

# %%
df_info = pd.DataFrame(abs(df.corr()['Female_Life_Expectancy']).sort_values()).reset_index()
df_info.rename(columns={"index": "Feature", "Female_Life_Expectancy": "Coefficient Correlation"}, inplace=True)
df_info
# Out:
#                    Feature  Coefficient Correlation
# 0               Open_Space                 0.022920
# 1                       Id                 0.035593
# 2     Not_English_Speaking                 0.066770
# 3                    Adult                 0.071700
# 4           Not_Born_In_UK                 0.097698
# 5       Cars_Per_Household                 0.117512
# 6               Crime_Rate                 0.128652
# 7                Non_White                 0.133413
# 8          Greater_Than_65                 0.163816
# 9   General_Fertility_Rate                 0.177026
# 10  Population_2011_Census                 0.251545
# 11        hh_Social_Rented                 0.261429
# 12                Children                 0.263822
# 13             Job_Seekers                 0.315908
# 14                 No_Qual                 0.319267
# 15    Male_Life_Expectancy                 0.383432
# 16         Life_Expectancy                 0.741153
# ...

# %% [markdown]
# Dropping all columns having corr coeff below 0.1

# %%
plt.scatter(np.log2(df['hh_Social_Rented']), df['Female_Life_Expectancy'], alpha= 0.4)
plt.xlabel('hh_Social_Rented')
plt.ylabel('Female_Life_Expectancy')
plt.show()

# %%
plt.scatter(np.log2(df['Children']), df['Female_Life_Expectancy'], alpha= 0.4)
plt.xlabel('Children')
plt.ylabel('Female_Life_Expectancy')
plt.show()

# %%
plt.scatter(np.log(df['Job_Seekers']), df['Female_Life_Expectancy'], alpha= 0.4)
plt.xlabel('Job_Seekers')
plt.ylabel('Female_Life_Expectancy')
plt.show()

# %%
plt.scatter(np.log(df['No_Qual']), df['Female_Life_Expectancy'], alpha= 0.4)
plt.xlabel('No_Qual')
plt.ylabel('Female_Life_Expectancy')
plt.show()

# %%
#Drop all features with corr < 0.1
df= df.drop(['Id', 'Open_Space', 'Not_English_Speaking', 'Adult', 'Not_Born_In_UK', 'Male_Life_Expectancy', 'Life_Expectancy'], axis= 1)
df.head()
# Out:
#    Population_2011_Census Ward_Code               Ward_Name District_Code  \
# 0                   11201    00ANGQ                    Town          00AN
# 1                   11518    00ANGA                 Addison          00AN
# 2                   10800    00ADGN  Falconwood and Welling          00AD
# 3                   12321    00BEGH            East Dulwich          00BE
# 4                   12609    00BCFZ             Barkingside          00BC
#
#                  District  Crime_Rate  hh_Social_Rented  Job_Seekers  No_Qual  \
# 0  Hammersmith and Fulham       117.7              23.7          3.6      9.4
# 1  Hammersmith and Fulham       114.0              24.9          4.5      9.3
# 2                  Bexley        44.2               1.1          2.9     22.1
# 3               Southwark        65.3              20.3          4.6     12.3
# 4               Redbridge        64.3               4.7          4.2     17.2
#
# ...

# %%
from sklearn.feature_selection import RFE
from sklearn.metrics import mean_absolute_error, mean_squared_error 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = df.drop(['District_Code', 'District', 'Female_Life_Expectancy', 'Ward_Code', 'Ward_Name'], axis=1)
y = df['Female_Life_Expectancy']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.33, random_state = 42)

train_mae = [] # Log training errors for each model
test_mae = [] # Log testing errors for each model
for i in range(1,len(X_train.columns)+1):
    rfe = RFE(estimator=LinearRegression(),n_features_to_select=i, verbose=0)
    rfe.fit(X_train,y_train)
    train_mae.append(mean_absolute_error(y_train, rfe.predict(X_train)))
    test_mae.append(mean_absolute_error(y_test, rfe.predict(X_test)))
    r_squared = rfe.score(X_train, y_train)
    print(r_squared)

x_axs2 = np.arange(1,len(X_train.columns)+1) # Create domain for plot
plt.figure(figsize=(10,8)) 
plt.plot(x_axs2, train_mae, label='Training MAE') # Plot training error over domain
plt.plot(x_axs2, test_mae, label='Testing MAE') # Plot testing error over domain
plt.xlabel('Maximum Depth') # Label x-axis
plt.ylabel('Total Error') # Label y-axis
plt.legend() # Show plot labels as legend
plt.show() # Show graph
# Out:
# 0.12945570838422082
# 0.14959144070484465
# 0.14974201397978437
# 0.1629512359150449
# 0.16340492502055426
# 0.17173844664377158
# 0.17271970012017668
# 0.1730048482049077
# 0.20156570386440098
# 0.22250508409992475

# %%
rfe = RFE(estimator=LinearRegression(),n_features_to_select=10, verbose=0)
rfe.fit(X_train,y_train)
fea = np.array(X_train.columns)
filter = rfe.get_support()
print("Selected features: {}".format(fea[filter]))
# Out:
# Selected features: ['Population_2011_Census' 'Crime_Rate' 'hh_Social_Rented' 'Job_Seekers'
#  'No_Qual' 'Cars_Per_Household' 'General_Fertility_Rate' 'Children'
#  'Greater_Than_65' 'Non_White']

# %%
X_train = X_train[fea[filter]]
X_test = X_test[fea[filter]]

# %%
sklearn_model= LinearRegression().fit(X_train, y_train)
sklearn_y_predictions= sklearn_model.predict(X_test)
r_squared = sklearn_model.score(X_train, y_train)
print(r_squared)
# Out:
# 0.22250508409992475

# %%
mean_absolute_error(sklearn_y_predictions, y_test)
# Out:
# 2.513546576589117

# %%
mean_squared_error(sklearn_y_predictions, y_test)
# Out:
# 9.629729950868798

# %%
#infos= pd.DataFrame({'MAE': list(),
#                     'MSE': list(mean_squared_error(sklearn_y_predictions, y_test))})
infos = pd.DataFrame([mean_absolute_error(sklearn_y_predictions, y_test)])
infos = infos.append(pd.DataFrame([mean_squared_error(sklearn_y_predictions, y_test)]))
infos = infos.T
infos.columns = ['MAE', 'MSE']
infos
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_17452\682619555.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   infos = infos.append(pd.DataFrame([mean_squared_error(sklearn_y_predictions, y_test)]))
#         MAE      MSE
# 0  2.513547  9.62973

# %%
predictions_df= pd.DataFrame({'Ward_code': df['Ward_Code'],
                             'Ward_name': df['Ward_Name'],
                             'Female_Life_Expectancy': df['Female_Life_Expectancy'],
                             'Life_Expectancy_Prediction': sklearn_model.predict(X[fea[filter]])})
predictions_df
# Out:
#     Ward_code                              Ward_name  Female_Life_Expectancy  \
# 0      00ANGQ                                   Town                    81.1
# 1      00ANGA                                Addison                    88.6
# 2      00ADGN                 Falconwood and Welling                    82.8
# 3      00BEGH                           East Dulwich                    82.9
# 4      00BCFZ                            Barkingside                    85.7
# ..        ...                                    ...                     ...
# 617    00BDFZ  Ham, Petersham and Richmond Riverside                    86.4
# 618    00ARGW                              Upminster                    81.6
# 619    00ASGN                              Harefield                    82.3
# 620    00AFGQ                                 Darwin                    82.4
# 621    00AZGW                         Telegraph Hill                    78.8
#
#      Life_Expectancy_Prediction
# ...
