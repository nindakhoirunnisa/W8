# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df_demographics = pd.read_csv("London ward data demographics(1).csv", sep='\t')
display(df_demographics.loc[521]['Wardname'])
# Out:
# 'Richmond upon Thames - Ham, Petersham & Richmond Riverside  19.1237762915576    16.7    15.9    30.5    7.6'

# %% [markdown]
# | Variable Name | Description |
# |:-------------------------------:|:-----------:|
# |       Wardname                 |  Wardname         |
# | Children | |
# | Greeaterthan65 | % All Older people aged 65+ - 2011 |
# | nonwhite | % BAME - 2011 |
# | NotBorninUK | % Not Born in UK - 2011 |
# | NotEnglishspeaking | % English is First Language of no one in the household - 2011 |

# %%
df_demographics.loc[520:522]
# Out:
#                                               Wardname   Children  \
# 520                          Islington - Saint Peter's  14.819827
# 521  Richmond upon Thames - Ham, Petersham & Richmo...        NaN
# 522    Richmond upon Thames - Mortlake & Barnes Common  19.791190
#
#      Greaterthan65  nonwhite  NotBorninUK  NotEnglishspeaking
# 520            9.8      25.6         32.0                 9.5
# 521            NaN       NaN          NaN                 NaN
# 522           12.0      11.7         25.6                 5.2

# %%
added = ["Richmond upon Thames - Ham, Petersham & Richmond Riverside", 19.1237762915576, 16.7, 15.9, 30.5, 7.6]

# %%
df_demographics.loc[521] = added
df_demographics
# Out:
#                                 Wardname   Children  Greaterthan65  nonwhite  \
# 0                 Hackney - Queensbridge  17.542063            8.2      44.7
# 1         Hammersmith & Fulham - S&s End  17.915361            8.4      30.6
# 2             Barking & Dagenham - River  26.851598           10.1      38.4
# 3    Tower Hamlets - Bethnal Green North  18.555872            7.0      49.4
# 4                         Merton - Abbey  15.731861            8.5      26.6
# ..                                   ...        ...            ...       ...
# 618                 Haringey - Harringay  14.767932            7.5      34.5
# 619                Lambeth - Coldharbour  21.562202            6.1      62.1
# 620              Newham - Plaistow North  23.600517            7.1      73.4
# 621               Greenwich - Abbey Wood  26.853031            9.6      46.3
# 622         Southwark - South Camberwell  19.684852            7.1      44.1
#
#      NotBorninUK  NotEnglishspeaking
# ...

# %%
#df_demographics.drop(df_demographics.index[[521]], inplace=True)

# %%
df_demographics.loc[520:522]
# Out:
#                                               Wardname   Children  \
# 520                          Islington - Saint Peter's  14.819827
# 521  Richmond upon Thames - Ham, Petersham & Richmo...  19.123776
# 522    Richmond upon Thames - Mortlake & Barnes Common  19.791190
#
#      Greaterthan65  nonwhite  NotBorninUK  NotEnglishspeaking
# 520            9.8      25.6         32.0                 9.5
# 521           16.7      15.9         30.5                 7.6
# 522           12.0      11.7         25.6                 5.2

# %%
info=pd.DataFrame(df_demographics.dtypes).T.rename(index={0:'Data type'})
info=info.append(pd.DataFrame(df_demographics.isna().sum()).T.rename(index={0:'Null values count'}))
info=info.append(pd.DataFrame(df_demographics.isna().sum()/df_demographics.shape[0]*100).T.
                         rename(index={0:'Null values (%)'}))
info=info.append(pd.DataFrame(df_demographics.min()).T.rename(index={0:'Min values'}))
info=info.append(pd.DataFrame(df_demographics.max()).T.rename(index={0:'Max values'}))
info
# Out:
#                                      Wardname   Children Greaterthan65  \
# Data type                              object    float64       float64
# Null values count                           0          0             0
# Null values (%)                           0.0        0.0           0.0
# Min values         Barking & Dagenham - Abbey   7.133676           3.5
# Max values           Westminster - Westbourne  33.187914          23.5
#
#                   nonwhite NotBorninUK NotEnglishspeaking
# Data type          float64     float64            float64
# Null values count        0           0                  0
# Null values (%)        0.0         0.0                0.0
# Min values             4.1         5.1                0.4
# Max values            93.7        68.5               99.7

# %% [markdown]
# | Variable Name | Description |
# |:-------------------------------:|:-----------:|
# |       Crimerate                 | Crime rate - 2011/12         |
# | Population2011Cencus | Population 2011 (Cencus) |
# | Openspace | % area that is open space - 2012 |

# %%
df_health = pd.read_csv("london ward data health(1).csv")
df_health
# Out:
#      Unnamed: 0                                   Wardname  \
# 0             0                           Bromley - Darwin
# 1             1    Kensington and Chelsea - Royal Hospital
# 2             2                     Hillingdon - Harefield
# 3             3  Hammersmith and Fulham - Palace Riverside
# 4             4         Kensington and Chelsea - Pembridge
# ..          ...                                        ...
# 617         617             Greenwich - Woolwich Riverside
# 618         618  Tower Hamlets - Blackwall and Cubitt Town
# 619         619            Greenwich - Thamesmead Moorings
# 620         620                       Barnet - Childs Hill
# 621         621                   Tower Hamlets - Millwall
#
#      Population2011Census  GeneralFertilityRate  Malelifeexpectancy  \
# 0                  5110.0                  63.8                81.2
# 1                  7252.0                  52.3                80.5
# ...

# %% [markdown]
# | Variable Name | Description |
# |:-------------------------------:|:-----------:|
# | GeneralFertilityRate | General Fertility Rate - 2011 |
# | Malelifeexpectancy | Male life expectancy - 2005-2009 |
# | Femalelifeexpectancy | Female life expectancy - 2005-2009 |

# %%
df_health = df_health.drop('Unnamed: 0', axis=1)
df_health
# Out:
#                                       Wardname  Population2011Census  \
# 0                             Bromley - Darwin                5110.0
# 1      Kensington and Chelsea - Royal Hospital                7252.0
# 2                       Hillingdon - Harefield                7399.0
# 3    Hammersmith and Fulham - Palace Riverside                7483.0
# 4           Kensington and Chelsea - Pembridge                7659.0
# ..                                         ...                   ...
# 617             Greenwich - Woolwich Riverside               19120.0
# 618  Tower Hamlets - Blackwall and Cubitt Town               19461.0
# 619            Greenwich - Thamesmead Moorings               19730.0
# 620                       Barnet - Childs Hill               20049.0
# 621                   Tower Hamlets - Millwall               23084.0
#
#      GeneralFertilityRate  Malelifeexpectancy  Femalelifeexpectancy
# 0                    63.8                81.2                  82.4
# ...

# %%
info=pd.DataFrame(df_health.dtypes).T.rename(index={0:'Data type'})
info=info.append(pd.DataFrame(df_health.isna().sum()).T.rename(index={0:'Null values count'}))
info=info.append(pd.DataFrame(df_health.isna().sum()/df_health.shape[0]*100).T.
                         rename(index={0:'Null values (%)'}))
info=info.append(pd.DataFrame(df_health.min()).T.rename(index={0:'Min values'}))
info=info.append(pd.DataFrame(df_health.max()).T.rename(index={0:'Max values'}))
info
# Out:
#                                        Wardname Population2011Census  \
# Data type                                object              float64
# Null values count                             0                    0
# Null values (%)                             0.0                  0.0
# Min values         Barking and Dagenham - Abbey               5110.0
# Max values             Westminster - Westbourne              23084.0
#
#                   GeneralFertilityRate Malelifeexpectancy Femalelifeexpectancy
# Data type                      float64            float64              float64
# Null values count                    0                  0                    0
# Null values (%)                    0.0                0.0                  0.0
# Min values                        22.1               71.2                 75.9
# Max values                       130.2              178.0                 99.6

# %%
#temp = df_health["Wardname"].str.split(" - ", n = 1, expand = True)
# 
#df_health["District"]= temp[0]
# 
# making separate last name column from new data frame
#df_health["Ward name"]= temp[1]
# 
# Dropping old Name columns
#df_health.drop(columns =["Wardname"], inplace = True)
 
#df_health

# %% [markdown]
# Population2011Census in df_health and df_environment doesn't have the same data type, so the one in df_health will be turnen into int.

# %%
df_health['Population2011Census'] = df_health['Population2011Census'].astype(int)
info=pd.DataFrame(df_health.dtypes).T.rename(index={0:'Data type'})
info=info.append(pd.DataFrame(df_health.isna().sum()).T.rename(index={0:'Null values count'}))
info=info.append(pd.DataFrame(df_health.isna().sum()/df_health.shape[0]*100).T.
                         rename(index={0:'Null values (%)'}))
info=info.append(pd.DataFrame(df_health.min()).T.rename(index={0:'Min values'}))
info=info.append(pd.DataFrame(df_health.max()).T.rename(index={0:'Max values'}))
info
# Out:
#                                        Wardname Population2011Census  \
# Data type                                object                int32
# Null values count                             0                    0
# Null values (%)                             0.0                  0.0
# Min values         Barking and Dagenham - Abbey                 5110
# Max values             Westminster - Westbourne                23084
#
#                   GeneralFertilityRate Malelifeexpectancy Femalelifeexpectancy
# Data type                      float64            float64              float64
# Null values count                    0                  0                    0
# Null values (%)                    0.0                0.0                  0.0
# Min values                        22.1               71.2                 75.9
# Max values                       130.2              178.0                 99.6

# %% [markdown]
# There are 2 empty rows in the joined table, as shown above. \n
# `00AYGN` = Lambeth - Stockwell
# `00BCGL` = Redbridge - Loxford
#
# Source: https://data.london.gov.uk/dataset/ward-profiles-and-atlas

# %%
df_demographics['Wardname'] = df_demographics['Wardname'].replace('&', 'and', regex=True)
df_health['Wardname'] = df_health['Wardname'].replace('&', 'and', regex=True)
df_demographics['Wardname'] = df_demographics['Wardname'].replace('St.', 'Saint', regex=True)
df_health['Wardname'] = df_health['Wardname'].replace('St.', 'Saint', regex=True)

# %%
#df_demographics[df_demographics['Wardname'].str.contains('Richmond upon Thames')]

# %%
#temp = df_demographics["Wardname"].str.split(" - ", n = 1, expand = True)
# 
#df_demographics["District"]= temp[0]
# 
# making separate last name column from new data frame
#df_demographics["Ward name"]= temp[1]
 
# Dropping old Name columns
#df_demographics.drop(columns =["Wardname"], inplace = True)
 
#df_demographics

# %%
health_demo=pd.merge(df_health,df_demographics,on='Wardname', how='left')
info=pd.DataFrame(health_demo.dtypes).T.rename(index={0:'Data type'})
info=info.append(pd.DataFrame(health_demo.isna().sum()).T.rename(index={0:'Null values count'}))
info
# Out:
#                   Wardname Population2011Census GeneralFertilityRate  \
# Data type           object                int32              float64
# Null values count        0                    0                    0
#
#                   Malelifeexpectancy Femalelifeexpectancy Children  \
# Data type                    float64              float64  float64
# Null values count                  0                    0        1
#
#                   Greaterthan65 nonwhite NotBorninUK NotEnglishspeaking
# Data type               float64  float64     float64            float64
# Null values count             1        1           1                  1

# %%
health_demo[health_demo['Children'].isna()]
# Out:
#                Wardname  Population2011Census  GeneralFertilityRate  \
# 67  Sutton - The Wrythe                 10163                  63.8
#
#     Malelifeexpectancy  Femalelifeexpectancy  Children  Greaterthan65  \
# 67                77.5                  83.9       NaN            NaN
#
#     nonwhite  NotBorninUK  NotEnglishspeaking
# 67       NaN          NaN                 NaN

# %%
temp = health_demo["Wardname"].str.split(" - ", n = 1, expand = True)
 
health_demo["District"]= temp[0]
 
#making separate last name column from new data frame
health_demo["Ward name"]= temp[1]

#Dropping old Name columns
health_demo.drop(columns =["Wardname"], inplace = True)

health_demo
# Out:
#      Population2011Census  GeneralFertilityRate  Malelifeexpectancy  \
# 0                    5110                  63.8                81.2
# 1                    7252                  52.3                80.5
# 2                    7399                  55.8                78.3
# 3                    7483                  40.0                80.9
# 4                    7659                  40.4                82.1
# ..                    ...                   ...                 ...
# 617                 19120                  84.4                73.8
# 618                 19461                  75.1                77.4
# 619                 19730                 122.5                74.3
# 620                 20049                  69.0                77.4
# 621                 23084                  58.1                83.6
#
#      Femalelifeexpectancy   Children  Greaterthan65  nonwhite  NotBorninUK  \
# ...

# %%
df_environment = pd.read_csv("London ward data environment(1).csv")
info=pd.DataFrame(df_environment.dtypes).T.rename(index={0:'Data type'})
info=info.append(pd.DataFrame(df_environment.isna().sum()).T.rename(index={0:'Null values count'}))
info=info.append(pd.DataFrame(df_environment.isna().sum()/df_environment.shape[0]*100).T.
                         rename(index={0:'Null values (%)'}))
info=info.append(pd.DataFrame(df_environment.min()).T.rename(index={0:'Min values'}))
info=info.append(pd.DataFrame(df_environment.max()).T.rename(index={0:'Max values'}))
info=info.append(pd.DataFrame(df_environment.nunique()).T.rename(index={0:'Number of unique value'}))
info
# Out:
#                        Wardcode Population2011Census Crimerate Openspace
# Data type                object                int64   float64   float64
# Null values count             0                    0         0         0
# Null values (%)             0.0                  0.0       0.0       0.0
# Min values               00ABFX                 5110       0.9       0.0
# Max values               00BKGW                23084    2100.2      99.9
# Number of unique value      624                  601       490       378

# %%
#df_environment['Wardcode'][0][0:4]

# %%
df_socio = pd.read_csv("London ward data socioeconomic(1).csv")
df_socio = df_socio.drop('Unnamed: 0', axis=1)
df_socio
# Out:
#     Wardcode  hhSocialRented  JobSeekers  Noqual  Carsperhousehold
# 0     00ABFX            26.7         8.7    16.4               0.5
# 1     00ABFY            36.8        10.2    31.2               0.8
# 2     00ABFZ            29.4        10.2    28.0               0.9
# 3     00ABGB            20.0         8.8    29.9               1.1
# 4     00ABGC            37.4        10.2    28.9               0.8
# ..       ...             ...         ...     ...               ...
# 652      NaN             NaN         NaN     NaN               NaN
# 653      NaN             NaN         NaN     NaN               NaN
# 654      NaN             NaN         NaN     NaN               NaN
# 655      NaN             NaN         NaN     NaN               NaN
# 656      NaN             NaN         NaN     NaN               NaN
#
# [657 rows x 5 columns]

# %%
info=pd.DataFrame(df_socio.dtypes).T.rename(index={0:'Data type'})
info=info.append(pd.DataFrame(df_socio.isna().sum()).T.rename(index={0:'Null values count'}))
info=info.append(pd.DataFrame(df_socio.isna().sum()/df_socio.shape[0]*100).T.
                         rename(index={0:'Null values (%)'}))
info=info.append(pd.DataFrame(df_socio.min()).T.rename(index={0:'Min values'}))
info=info.append(pd.DataFrame(df_socio.max()).T.rename(index={0:'Max values'}))
info=info.append(pd.DataFrame(df_socio.nunique()).T.rename(index={0:'Number of unique value'}))
info
# Out:
#                         Wardcode hhSocialRented JobSeekers    Noqual  \
# Data type                 object        float64    float64   float64
# Null values count             36             36         36        36
# Null values (%)         5.479452       5.479452   5.479452  5.479452
# Min values                   NaN            1.1        0.4       3.8
# Max values                   NaN           68.4       31.6      35.8
# Number of unique value       621            346        130       224
#
#                        Carsperhousehold
# Data type                       float64
# Null values count                    36
# Null values (%)                5.479452
# Min values                          0.2
# Max values                          7.2
# Number of unique value               17

# %%
df_socio = df_socio.dropna()
df_socio
# Out:
#     Wardcode  hhSocialRented  JobSeekers  Noqual  Carsperhousehold
# 0     00ABFX            26.7         8.7    16.4               0.5
# 1     00ABFY            36.8        10.2    31.2               0.8
# 2     00ABFZ            29.4        10.2    28.0               0.9
# 3     00ABGB            20.0         8.8    29.9               1.1
# 4     00ABGC            37.4        10.2    28.9               0.8
# ..       ...             ...         ...     ...               ...
# 616   00BKGR            29.3         2.7    12.5               0.4
# 617   00BKGS            34.5         4.3    11.7               0.4
# 618   00BKGT            28.2         4.0     9.4               0.5
# 619   00BKGU            48.5        10.0    22.4               0.4
# 620   00BKGW            23.5         3.4     9.6               0.4
#
# [621 rows x 5 columns]

# %%
df_environment[df_environment['Wardcode'].str.len() != 6]
# Out:
#      Wardcode  Population2011Census  Crimerate  Openspace
# 126  00BAGDag                  9816       61.0       12.3

# %%
#df_environment.loc[126]['Wardcode'] = df_environment.loc[126]['Wardcode'][0:6]
df_environment.loc[126,['Wardcode']] = df_environment.loc[126]['Wardcode'][0:6]

# %%
df_socio[df_socio['Wardcode'].str.len() != 6]
# Out:
#     Wardcode  hhSocialRented  JobSeekers  Noqual  Carsperhousehold
# 107  00AGGK#            45.9         6.3    17.8               0.5

# %%
df_socio.loc[107,['Wardcode']] = df_socio.loc[107]['Wardcode'][0:6]

# %%
envi_socio=pd.merge(df_environment,df_socio,on='Wardcode', how='left')
info=pd.DataFrame(envi_socio.dtypes).T.rename(index={0:'Data type'})
info=info.append(pd.DataFrame(envi_socio.isna().sum()).T.rename(index={0:'Null values count'}))
info
# Out:
#                   Wardcode Population2011Census Crimerate Openspace  \
# Data type           object                int64   float64   float64
# Null values count        0                    0         0         0
#
#                   hhSocialRented JobSeekers   Noqual Carsperhousehold
# Data type                float64    float64  float64          float64
# Null values count              3          3        3                3

# %% [markdown]
# Now we got two joined table:
# - Health and Demographic
# - Socioenonomic and Environment

# %%
info=pd.DataFrame(health_demo.dtypes).T.rename(index={0:'Data type'})
info=info.append(pd.DataFrame(health_demo.isna().sum()).T.rename(index={0:'Null values count'}))
info=info.append(pd.DataFrame(health_demo.isna().sum()/health_demo.shape[0]*100).T.
                         rename(index={0:'Null values (%)'}))
info=info.append(pd.DataFrame(health_demo.min()).T.rename(index={0:'Min values'}))
info=info.append(pd.DataFrame(health_demo.max()).T.rename(index={0:'Max values'}))
info=info.append(pd.DataFrame(health_demo.nunique()).T.rename(index={0:'Number of unique value'}))
info
# Out:
#                        Population2011Census GeneralFertilityRate  \
# Data type                             int32              float64
# Null values count                         0                    0
# Null values (%)                         0.0                  0.0
# Min values                             5110                 22.1
# Max values                            23084                130.2
# Number of unique value                  599                  407
#
#                        Malelifeexpectancy Femalelifeexpectancy   Children  \
# Data type                         float64              float64    float64
# Null values count                       0                    0          1
# Null values (%)                       0.0                  0.0   0.160772
# Min values                           71.2                 75.9   7.133676
# Max values                          178.0                 99.6  33.187914
# ...

# %%
info=pd.DataFrame(envi_socio.dtypes).T.rename(index={0:'Data type'})
info=info.append(pd.DataFrame(envi_socio.isna().sum()).T.rename(index={0:'Null values count'}))
info=info.append(pd.DataFrame(envi_socio.isna().sum()/envi_socio.shape[0]*100).T.
                         rename(index={0:'Null values (%)'}))
info=info.append(pd.DataFrame(envi_socio.min()).T.rename(index={0:'Min values'}))
info=info.append(pd.DataFrame(envi_socio.max()).T.rename(index={0:'Max values'}))
info=info.append(pd.DataFrame(envi_socio.nunique()).T.rename(index={0:'Number of unique value'}))
info
# Out:
#                        Wardcode Population2011Census Crimerate Openspace  \
# Data type                object                int64   float64   float64
# Null values count             0                    0         0         0
# Null values (%)             0.0                  0.0       0.0       0.0
# Min values               00ABFX                 5110       0.9       0.0
# Max values               00BKGW                23084    2100.2      99.9
# Number of unique value      624                  601       490       378
#
#                        hhSocialRented JobSeekers    Noqual Carsperhousehold
# Data type                     float64    float64   float64          float64
# Null values count                   3          3         3                3
# Null values (%)              0.480769   0.480769  0.480769         0.480769
# Min values                        1.1        0.4       3.8              0.2
# Max values                       68.4       31.6      35.8              7.2
# ...

# %% [markdown]
# Your task is to build a model which predicts life expectancy **at the ward level**. So we need some linkage between `envi_socio` and `health_demo`. Both joined table had `Population2011Census`, but the number of their unique values are not the same and their unique values < length of the table. So there might be some duplicate value. Thus, we need another attribute that can be used to link both table and `District` is chosen.
# - We need `Districtcode` that was generated from `District` in `health_demo`
# - We need `Districtcode` that was generated from the first 4 characters in `Wardcode`

# %%
district_code = []
for i in envi_socio.index:
    district_code.append(envi_socio['Wardcode'][i][0:4])
    #envi_socio['Districtcode'].iloc[i] = envi_socio['Wardcode'][i][0:4]
envi_socio['Districtcode'] = district_code
envi_socio
# Out:
#     Wardcode  Population2011Census  Crimerate  Openspace  hhSocialRented  \
# 0     00ANGQ                 11201      117.7        0.0            23.7
# 1     00ANGA                 11518      114.0        0.3            24.9
# 2     00ADGN                 10800       44.2        0.7             1.1
# 3     00BEGH                 12321       65.3        0.7            20.3
# 4     00BCFZ                 12609       64.3        1.3             4.7
# ..       ...                   ...        ...        ...             ...
# 619   00BDFZ                 10317       65.8       81.9            18.5
# 620   00ARGW                 12833       49.5       82.0             1.9
# 621   00ASGN                  7399       67.4       85.5            24.0
# 622   00AFGQ                  5110       58.6       88.8             5.5
# 623   00AZGW                 16414       71.7       99.9            36.6
#
#      JobSeekers  Noqual  Carsperhousehold Districtcode
# ...

# %%
df_districtcode = pd.read_csv("London District codes(1).csv")
df_districtcode.head()
# Out:
#                District Districtcode
# 0  Barking and Dagenham         00AB
# 1                Barnet         00AC
# 2                Bexley         00AD
# 3                 Brent         00AE
# 4               Bromley         00AF

# %%
key_list = list(health_demo['District'])
dict_lookup = dict(zip(df_districtcode['District'], df_districtcode['Districtcode']))

health_demo['Districtcode'] = [dict_lookup[item] for item in key_list]
for i in health_demo.index:
    health_demo['Districtcode'][i] = health_demo['Districtcode'][i][1:5]
health_demo
# Out:
#      Population2011Census  GeneralFertilityRate  Malelifeexpectancy  \
# 0                    5110                  63.8                81.2
# 1                    7252                  52.3                80.5
# 2                    7399                  55.8                78.3
# 3                    7483                  40.0                80.9
# 4                    7659                  40.4                82.1
# ..                    ...                   ...                 ...
# 617                 19120                  84.4                73.8
# 618                 19461                  75.1                77.4
# 619                 19730                 122.5                74.3
# 620                 20049                  69.0                77.4
# 621                 23084                  58.1                83.6
#
#      Femalelifeexpectancy   Children  Greaterthan65  nonwhite  NotBorninUK  \
# ...

# %%
df = pd.merge(envi_socio, health_demo, on=['Population2011Census', 'Districtcode'], how='left')
info=pd.DataFrame(df.dtypes).T.rename(index={0:'Data type'})
info=info.append(pd.DataFrame(df.isna().sum()).T.rename(index={0:'Null values count'}))
info
# Out:
#                   Wardcode Population2011Census Crimerate Openspace  \
# Data type           object                int64   float64   float64
# Null values count        0                    0         0         0
#
#                   hhSocialRented JobSeekers   Noqual Carsperhousehold  \
# Data type                float64    float64  float64          float64
# Null values count              3          3        3                3
#
#                   Districtcode GeneralFertilityRate Malelifeexpectancy  \
# Data type               object              float64            float64
# Null values count            0                    2                  2
#
#                   Femalelifeexpectancy Children Greaterthan65 nonwhite  \
# Data type                      float64  float64       float64  float64
# Null values count                    2        3             3        3
#
#                   NotBorninUK NotEnglishspeaking District Ward name
# ...

# %%
df['Adult'] = (100 - df['Children'] - df['Greaterthan65'])
col = df.loc[:, "Malelifeexpectancy":"Femalelifeexpectancy"]
df['LifeExpectancy'] = col.mean(axis=1)
df
# Out:
#     Wardcode  Population2011Census  Crimerate  Openspace  hhSocialRented  \
# 0     00ANGQ                 11201      117.7        0.0            23.7
# 1     00ANGA                 11518      114.0        0.3            24.9
# 2     00ADGN                 10800       44.2        0.7             1.1
# 3     00BEGH                 12321       65.3        0.7            20.3
# 4     00BCFZ                 12609       64.3        1.3             4.7
# ..       ...                   ...        ...        ...             ...
# 619   00BDFZ                 10317       65.8       81.9            18.5
# 620   00ARGW                 12833       49.5       82.0             1.9
# 621   00ASGN                  7399       67.4       85.5            24.0
# 622   00AFGQ                  5110       58.6       88.8             5.5
# 623   00AZGW                 16414       71.7       99.9            36.6
#
#      JobSeekers  Noqual  Carsperhousehold Districtcode  GeneralFertilityRate  \
# ...

# %%
df = df[['Population2011Census', 'Wardcode', 'Ward name', 'Districtcode', 'District', 'Crimerate', 'Openspace', 'hhSocialRented', 'JobSeekers', 'Noqual', 'Carsperhousehold', 'GeneralFertilityRate', 'Malelifeexpectancy', 'Femalelifeexpectancy', 'LifeExpectancy', 'Children', 'Adult', 'Greaterthan65', 'nonwhite', 'NotBorninUK', 'NotEnglishspeaking']]
df
# Out:
#      Population2011Census Wardcode                              Ward name  \
# 0                   11201   00ANGQ                                   Town
# 1                   11518   00ANGA                                Addison
# 2                   10800   00ADGN                 Falconwood and Welling
# 3                   12321   00BEGH                           East Dulwich
# 4                   12609   00BCFZ                            Barkingside
# ..                    ...      ...                                    ...
# 619                 10317   00BDFZ  Ham, Petersham and Richmond Riverside
# 620                 12833   00ARGW                              Upminster
# 621                  7399   00ASGN                              Harefield
# 622                  5110   00AFGQ                                 Darwin
# 623                 16414   00AZGW                         Telegraph Hill
#
#     Districtcode                District  Crimerate  Openspace  \
# ...

# %%
df.to_csv("dataset_ward_level.csv")

# %%
cols = [ val for val in df.columns if val != 'Population2011Census']
grouped_ = round(pd.concat([df.groupby(['Districtcode', 'District'])[cols].mean(), df.groupby(['Districtcode', 'District'])['Population2011Census'].sum()], axis=1).reset_index(),3)
grouped_.to_csv("dataset_district_level.csv")
grouped_
# Out:
#    Districtcode                District  Crimerate  Openspace  hhSocialRented  \
# 0          00AB    Barking and Dagenham    101.059     28.565          33.419
# 1          00AC                  Barnet     75.829     31.290          14.238
# 2          00AD                  Bexley     53.486     30.433          14.067
# 3          00AE                   Brent    106.410     20.743          22.452
# 4          00AF                 Bromley     67.214     42.345          13.473
# 5          00AG                  Camden    164.933     16.878          33.183
# 6          00AH                 Croydon     87.275     24.662          18.196
# 7          00AJ                  Ealing     96.048     28.574          18.000
# 8          00AK                 Enfield     74.119     35.571          17.105
# 9          00AL               Greenwich     87.876     37.006          33.606
# 10         00AM                 Hackney    115.042     24.095          43.611
# ...
