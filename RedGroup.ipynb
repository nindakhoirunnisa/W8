# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("C:/Users/prani/OneDrive/Documents/Desktop/UDATE/Red_Group_Ass/dataset_district_level_cleaned.csv")
df
# Out:
#     Id District_Code                District  Crime_Rate  Open_Space  \
# 0    0          00AB    Barking and Dagenham       101.1        28.6
# 1    1          00AC                  Barnet        75.8        31.3
# 2    2          00AD                  Bexley        53.5        30.4
# 3    3          00AE                   Brent       106.4        20.7
# 4    4          00AF                 Bromley        67.2        42.3
# 5    5          00AG                  Camden       164.9        16.9
# 6    6          00AH                 Croydon        87.3        24.7
# 7    7          00AJ                  Ealing        96.0        28.6
# 8    8          00AK                 Enfield        74.1        35.6
# 9    9          00AL               Greenwich        87.9        37.0
# 10  10          00AM                 Hackney       115.0        24.1
# 11  11          00AN  Hammersmith and Fulham       121.8        14.3
# 12  12          00AP                Haringey       105.1        25.8
# 13  13          00AQ                  Harrow        59.0        24.1
# 14  14          00AR                Havering        71.2        44.5
# 15  15          00AS              Hillingdon        93.5        39.4
# 16  16          00AT                Hounslow       101.0        33.0
# 17  17          00AU               Islington       127.1        13.5
# 18  18          00AW  Kensington and Chelsea       123.8        18.0
# 19  19          00AX    Kingston upon Thames        69.4        27.3
# 20  20          00AY                 Lambeth       125.3        20.0
# 21  21          00AZ                Lewisham        97.9        25.4
# 22  22          00BA                  Merton        69.3        29.0
# 23  23          00BB                  Newham       103.5        20.7
# 24  24          00BC               Redbridge        87.2        28.5
# 25  25          00BD    Richmond upon Thames        61.8        46.9
# 26  26          00BE               Southwark       114.2        17.8
# 27  27          00BF                  Sutton        60.7        26.1
# 28  28          00BG           Tower Hamlets       117.0        21.8
# 29  29          00BH          Waltham Forest        98.9        28.5
# 30  30          00BJ              Wandsworth        77.3        25.0
# 31  31          00BK             Westminster       307.4        18.4
#
#     hh_Social_Rented  Job_Seekers  No_Qual  Cars_Per_Household  \
# 0               33.4          9.6     28.1                 0.8
# 1               14.2          4.3     15.5                 1.4
# 2               14.1          4.3     23.0                 1.2
# 3               22.5          7.8     19.2                 0.8
# 4               13.5          3.9     18.1                 1.2
# 5               33.2          5.5     12.6                 0.5
# 6               18.2          6.3     18.1                 1.0
# 7               18.0          6.2     16.5                 0.9
# 8               17.1          7.9     22.9                 1.0
# 9               33.6          7.4     20.9                 0.8
# 10              43.6         10.3     20.0                 0.4
# 11              31.1          5.0     12.8                 0.6
# 12              26.4          9.4     17.5                 0.6
# 13              10.3          3.8     16.7                 1.2
# 14              13.8          6.4     26.5                 1.2
# 15              16.6          4.0     19.1                 1.2
# 16              22.5          4.4     17.4                 1.0
# 17              42.0          6.5     17.0                 0.4
# 18              25.1          4.3     10.2                 0.6
# 19              11.7          2.4     13.7                 1.1
# 20              34.1          7.7     13.9                 0.5
# 21              30.9          7.9     18.0                 0.7
# 22              13.7          4.2     15.1                 0.9
# 23              28.8          9.6     20.7                 0.6
# 24              10.5          5.7     18.3                 1.1
# 25              12.7          2.1     10.7                 1.1
# 26              43.6          7.9     16.4                 0.5
# 27              14.2          3.8     18.6                 1.2
# 28              40.3         10.8     20.1                 0.4
# 29              21.9          8.9     21.0                 0.8
# 30              20.2          3.9     11.6                 0.7
# 31              26.5          5.1     12.9                 0.5
#
#     General_Fertility_Rate  Male_Life_Expectancy  Female_Life_Expectancy  \
# 0                     93.9                  77.0                    81.9
# 1                     72.0                  79.4                    83.7
# 2                     66.9                  79.0                    83.6
# 3                     81.1                  79.5                    86.0
# 4                     61.6                  79.5                    83.8
# 5                     54.5                  77.9                    83.1
# 6                     72.7                  78.7                    82.7
# 7                     78.0                  79.0                    85.0
# 8                     74.8                  78.5                    82.9
# 9                     81.2                  75.7                    82.8
# 10                    71.4                  76.5                    83.3
# 11                    49.3                  78.2                    84.7
# 12                    64.2                  76.2                    83.7
# 13                    68.5                  80.0                    85.0
# 14                    58.7                  78.2                    82.7
# 15                    70.9                  77.9                    83.5
# 16                    81.2                  78.3                    83.8
# 17                    47.7                  75.3                    81.8
# 18                    54.0                  84.3                    87.7
# 19                    61.0                  79.5                    84.1
# 20                    56.2                  76.1                    81.6
# 21                    69.2                  75.9                    80.9
# 22                    79.1                  80.3                    84.7
# 23                    82.5                  76.3                    80.9
# 24                    78.6                  79.1                    83.4
# 25                    70.9                  80.6                    85.5
# 26                    63.4                  77.5                    83.5
# 27                    65.7                  84.4                    83.1
# 28                    65.6                  77.0                    83.9
# 29                    85.9                  77.0                    82.4
# 30                    59.0                  77.1                    82.0
# 31                    52.1                  82.8                    87.4
#
#     Children  Adult  Greater_Than_65  Non_White  Not_Born_In_UK  \
# 0       25.9   63.5             10.5       41.0            30.3
# 1       20.8   65.8             13.4       35.5            38.4
# 2       20.4   63.4             16.2       17.7            13.8
# 3       20.0   69.3             10.6       63.8            55.2
# 4       19.5   63.5             17.0       15.2            14.1
# 5       16.0   73.0             10.9       33.5            42.4
# 6       21.7   65.7             12.6       42.7            28.2
# 7       20.3   69.0             10.7       51.0            48.1
# 8       22.1   65.2             12.7       37.9            34.5
# 9       21.4   67.8             10.8       35.3            29.6
# 10      20.9   72.0              7.1       45.3            39.0
# 11      16.3   74.6              9.1       31.4            42.5
# 12      20.2   70.9              8.9       38.3            43.6
# 13      20.1   65.7             14.2       57.5            44.5
# 14      18.7   63.4             18.0       12.2            10.1
# 15      20.6   66.2             13.3       37.7            29.0
# 16      20.2   69.1             10.7       48.0            42.9
# 17      15.9   75.3              8.8       31.5            35.2
# 18      15.3   72.5             12.2       29.0            51.4
# 19      19.0   68.1             12.9       25.6            28.2
# 20      18.0   74.3              7.7       42.5            38.4
# 21      20.8   69.7              9.6       46.2            33.5
# 22      19.4   68.9             11.7       34.5            37.6
# 23      22.7   70.6              6.7       70.8            53.6
# 24      21.9   65.6             12.5       54.0            35.0
# 25      19.7   66.7             13.6       14.1            24.2
# 26      18.6   73.6              7.8       45.4            39.2
# 27      19.9   65.6             14.5       21.6            20.1
# 28      19.7   74.0              6.2       54.8            42.7
# 29      21.2   68.5             10.3       46.5            37.4
# 30      16.6   74.7              8.8       28.3            35.2
# 31      14.6   74.1             11.3       37.4            52.9
#
#     Not_English_Speaking  Population_2011_Census  Life_Expectancy
# 0                   10.0                  185911             79.5
# 1                   14.3                  356386             81.6
# 2                    2.8                  231997             81.3
# 3                   22.8                  311215             82.8
# 4                    2.9                  309392             81.6
# 5                   14.4                  220338             80.5
# 6                    7.3                  363378             80.7
# 7                   21.4                  338449             82.0
# 8                   13.9                  312466             80.7
# 9                    8.6                  254557             79.3
# 10                  14.5                  246270             79.9
# 11                  14.3                  182493             81.4
# 12                  18.2                  254926             79.9
# 13                  16.0                  239056             82.5
# 14                   2.2                  237232             80.4
# 15                   9.6                  273936             80.7
# 16                  17.5                  253958             81.0
# 17                  12.1                  206125             78.5
# 18                  20.5                  158649             86.0
# 19                   9.2                  160060             81.8
# 20                  11.8                  288309             78.8
# 21                   9.1                  275885             78.4
# 22                  11.9                  199693             82.5
# 23                  24.7                  307984             78.6
# 24                  11.9                  262426             81.2
# 25                   6.0                  186990             83.1
# 26                  10.9                  288283             80.5
# 27                  10.8                  190146             83.7
# 28                  19.3                  254096             80.4
# 29                  14.1                  258249             79.7
# 30                   9.8                  306995             79.6
# 31                  21.9                  219396             85.1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      32 non-null     int64
#  1   District_Code           32 non-null     object
#  2   District                32 non-null     object
#  3   Crime_Rate              32 non-null     float64
#  4   Open_Space              32 non-null     float64
#  5   hh_Social_Rented        32 non-null     float64
#  6   Job_Seekers             32 non-null     float64
#  7   No_Qual                 32 non-null     float64
#  8   Cars_Per_Household      32 non-null     float64
#  9   General_Fertility_Rate  32 non-null     float64
#  10  Male_Life_Expectancy    32 non-null     float64
#  11  Female_Life_Expectancy  32 non-null     float64
#  12  Children                32 non-null     float64
#  13  Adult                   32 non-null     float64
#  14  Greater_Than_65         32 non-null     float64
#  15  Non_White               32 non-null     float64
#  16  Not_Born_In_UK          32 non-null     float64
#  17  Not_English_Speaking    32 non-null     float64
#  18  Population_2011_Census  32 non-null     int64
#  19  Life_Expectancy         32 non-null     float64
# dtypes: float64(16), int64(2), object(2)
# memory usage: 5.1+ KB

# %%
df.describe().transpose()
# Out:
#                         count           mean           std       min  \
# Id                       32.0      15.500000      9.380832       0.0
# Crime_Rate               32.0     100.675000     45.210511      53.5
# Open_Space               32.0      27.131250      8.452464      13.5
# hh_Social_Rented         32.0      23.696875     10.335142      10.3
# Job_Seekers              32.0       6.165625      2.364333       2.1
# No_Qual                  32.0      17.596875      4.210853      10.2
# Cars_Per_Household       32.0       0.840625      0.294968       0.4
# General_Fertility_Rate   32.0      68.493750     11.360825      47.7
# Male_Life_Expectancy     32.0      78.521875      2.249836      75.3
# Female_Life_Expectancy   32.0      83.596875      1.601508      80.9
# Children                 32.0      19.637500      2.367488      14.6
# Adult                    32.0      69.071875      3.835676      63.4
# Greater_Than_65          32.0      11.290625      2.905097       6.2
# Non_White                32.0      38.318750     14.054719      12.2
# Not_Born_In_UK           32.0      35.962500     11.329031      10.1
# Not_English_Speaking     32.0      12.959375      5.798768       2.2
# Population_2011_Census   32.0  254226.437500  54840.565720  158649.0
# Life_Expectancy          32.0      81.053125      1.797128      78.4
#
#                                25%        50%         75%       max
# Id                           7.750      15.50      23.250      31.0
# Crime_Rate                  73.375      96.95     114.400     307.4
# Open_Space                  20.700      25.95      30.625      46.9
# hh_Social_Rented            14.175      22.20      31.625      43.6
# Job_Seekers                  4.275       5.95       7.900      10.8
# No_Qual                     14.800      17.75      20.025      28.1
# Cars_Per_Household           0.600       0.80       1.100       1.4
# General_Fertility_Rate      60.500      68.85      78.150      93.9
# Male_Life_Expectancy        77.000      78.25      79.500      84.4
# Female_Life_Expectancy      82.700      83.50      84.250      87.7
# Children                    18.675      20.05      20.825      25.9
# Adult                       65.700      68.95      72.625      75.3
# Greater_Than_65              9.050      10.85      13.000      18.0
# Non_White                   30.800      37.80      46.275      70.8
# Not_Born_In_UK              29.450      37.50      42.750      55.2
# Not_English_Speaking         9.500      12.00      16.375      24.7
# Population_2011_Census  216078.250  254326.50  292980.500  363378.0
# Life_Expectancy             79.850      80.70      81.850      86.0

# %%
df.corr()['Life_Expectancy']
# Out:
# Id                        0.084479
# Crime_Rate                0.198550
# Open_Space                0.015029
# hh_Social_Rented         -0.449398
# Job_Seekers              -0.568038
# No_Qual                  -0.427531
# Cars_Per_Household        0.271463
# General_Fertility_Rate   -0.187826
# Male_Life_Expectancy      0.951351
# Female_Life_Expectancy    0.904213
# Children                 -0.369868
# Adult                    -0.106754
# Greater_Than_65           0.439838
# Non_White                -0.238099
# Not_Born_In_UK            0.155135
# Not_English_Speaking      0.220857
# Population_2011_Census   -0.334683
# Life_Expectancy           1.000000
# Name: Life_Expectancy, dtype: float64

# %% [markdown]
# Positive corr with Crime_Rate(low), Open_Space(negligible), Cars_Per_Household, Male_Life_Expectancy, Female_Life_Expectancy, Greater_Than_65, Not_Born_In_UK(low), Not_English_Speaking
#
# Dropping all columns having corr coeff below 0.2

# %%
df= df.drop(['Id', 'Crime_Rate', 'Open_Space', 'hh_Social_Rented', 'Job_Seekers', 'No_Qual', 'General_Fertility_Rate', 'Children', 'Adult', 'Non_White', 'Not_Born_In_UK','Population_2011_Census'], axis= 1)

# %%
df.head()
# Out:
#   District_Code              District  Cars_Per_Household  \
# 0          00AB  Barking and Dagenham                 0.8
# 1          00AC                Barnet                 1.4
# 2          00AD                Bexley                 1.2
# 3          00AE                 Brent                 0.8
# 4          00AF               Bromley                 1.2
#
#    Male_Life_Expectancy  Female_Life_Expectancy  Greater_Than_65  \
# 0                  77.0                    81.9             10.5
# 1                  79.4                    83.7             13.4
# 2                  79.0                    83.6             16.2
# 3                  79.5                    86.0             10.6
# 4                  79.5                    83.8             17.0
#
#    Not_English_Speaking  Life_Expectancy
# 0                  10.0             79.5
# 1                  14.3             81.6
# 2                   2.8             81.3
# 3                  22.8             82.8
# 4                   2.9             81.6

# %%
plt.scatter(df['Male_Life_Expectancy'], df['Life_Expectancy'], alpha= 0.4)
plt.xlabel('Male_Life_Expectancy')
plt.ylabel('Life_Expectancy')
plt.show()

# %%
plt.scatter(df['Female_Life_Expectancy'], df['Life_Expectancy'], alpha= 0.6)
plt.xlabel('Female_Life_Expectancy')
plt.ylabel('Life_Expectancy')
plt.show()

# %%
plt.scatter(df['Greater_Than_65'], df['Life_Expectancy'], alpha= 0.7)
plt.xlabel('Greater_Than_65')
plt.ylabel('Life_Expectancy')
plt.show()

# %%
plt.scatter(df['Not_English_Speaking'], df['Life_Expectancy'], alpha= 0.7)
plt.xlabel('Not_English_Speaking')
plt.ylabel('Life_Expectancy')
plt.show()

# %%
plt.scatter(df['Cars_Per_Household'], df['Life_Expectancy'], alpha= 0.7)
plt.xlabel('Cars_Per_Household')
plt.ylabel('Life_Expectancy')
plt.show()

# %%
df_np=df.to_numpy()

# %%
X_train, y_train= df_np[:, 2:7] , df_np[:, -1]
X_train.shape
# Out:
# (32, 5)

# %%
y_train.shape
# Out:
# (32,)

# %%
from sklearn.linear_model import LinearRegression

# %%
sklearn_model= LinearRegression().fit(X_train, y_train)
sklearn_y_predictions= sklearn_model.predict(X_train)
sklearn_y_predictions
# Out:
# array([79.43921187, 81.56459744, 81.29159977, 82.75302689, 81.63592379,
#        80.46791749, 80.69358012, 82.00358048, 80.68711562, 79.248335  ,
#        79.89488054, 81.45211017, 79.94446426, 82.50179205, 80.42207239,
#        80.70771448, 81.05654215, 78.52398175, 85.98424951, 81.80629628,
#        78.8370024 , 78.38393586, 82.5019149 , 78.58076174, 81.2512073 ,
#        83.06414833, 80.50051515, 83.73167027, 80.45045704, 79.69016282,
#        79.54639176, 85.08284037])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error 
mean_absolute_error(sklearn_y_predictions, y_train)
# Out:
# 0.026702803444962342

# %% [markdown]
# MAE refers to average of difference between true value and prediction. Since, it is 0.0267 means the predicted values are close to true values.

# %%
mean_squared_error(sklearn_y_predictions, y_train)
# Out:
# 0.0010776878457292875

# %% [markdown]
# MSE measures amount of error in the statistical model. MSE value is near zero and is non-negative. Therefore, good fit.

# %%
predictions_df= pd.DataFrame({'Cars_Per_Household': df['Cars_Per_Household'],
                             'Male_Life_Expectancy': df['Male_Life_Expectancy'],
                             'Female_Life_Expectancy': df['Female_Life_Expectancy'],
                             'Greater_Than_65': df['Greater_Than_65'],
                             'Not_English_Speaking': df['Not_English_Speaking'],
                             'Life_Expectancy': df['Life_Expectancy'],
                             'Life_Expectancy_Prediction': sklearn_y_predictions})
predictions_df
# Out:
#     Cars_Per_Household  Male_Life_Expectancy  Female_Life_Expectancy  \
# 0                  0.8                  77.0                    81.9
# 1                  1.4                  79.4                    83.7
# 2                  1.2                  79.0                    83.6
# 3                  0.8                  79.5                    86.0
# 4                  1.2                  79.5                    83.8
# 5                  0.5                  77.9                    83.1
# 6                  1.0                  78.7                    82.7
# 7                  0.9                  79.0                    85.0
# 8                  1.0                  78.5                    82.9
# 9                  0.8                  75.7                    82.8
# 10                 0.4                  76.5                    83.3
# 11                 0.6                  78.2                    84.7
# 12                 0.6                  76.2                    83.7
# 13                 1.2                  80.0                    85.0
# 14                 1.2                  78.2                    82.7
# 15                 1.2                  77.9                    83.5
# 16                 1.0                  78.3                    83.8
# 17                 0.4                  75.3                    81.8
# 18                 0.6                  84.3                    87.7
# 19                 1.1                  79.5                    84.1
# 20                 0.5                  76.1                    81.6
# 21                 0.7                  75.9                    80.9
# 22                 0.9                  80.3                    84.7
# 23                 0.6                  76.3                    80.9
# 24                 1.1                  79.1                    83.4
# 25                 1.1                  80.6                    85.5
# 26                 0.5                  77.5                    83.5
# 27                 1.2                  84.4                    83.1
# 28                 0.4                  77.0                    83.9
# 29                 0.8                  77.0                    82.4
# 30                 0.7                  77.1                    82.0
# 31                 0.5                  82.8                    87.4
#
#     Greater_Than_65  Not_English_Speaking  Life_Expectancy  \
# 0              10.5                  10.0             79.5
# 1              13.4                  14.3             81.6
# 2              16.2                   2.8             81.3
# 3              10.6                  22.8             82.8
# 4              17.0                   2.9             81.6
# 5              10.9                  14.4             80.5
# 6              12.6                   7.3             80.7
# 7              10.7                  21.4             82.0
# 8              12.7                  13.9             80.7
# 9              10.8                   8.6             79.3
# 10              7.1                  14.5             79.9
# 11              9.1                  14.3             81.4
# 12              8.9                  18.2             79.9
# 13             14.2                  16.0             82.5
# 14             18.0                   2.2             80.4
# 15             13.3                   9.6             80.7
# 16             10.7                  17.5             81.0
# 17              8.8                  12.1             78.5
# 18             12.2                  20.5             86.0
# 19             12.9                   9.2             81.8
# 20              7.7                  11.8             78.8
# 21              9.6                   9.1             78.4
# 22             11.7                  11.9             82.5
# 23              6.7                  24.7             78.6
# 24             12.5                  11.9             81.2
# 25             13.6                   6.0             83.1
# 26              7.8                  10.9             80.5
# 27             14.5                  10.8             83.7
# 28              6.2                  19.3             80.4
# 29             10.3                  14.1             79.7
# 30              8.8                   9.8             79.6
# 31             11.3                  21.9             85.1
#
#     Life_Expectancy_Prediction
# 0                    79.439212
# 1                    81.564597
# 2                    81.291600
# 3                    82.753027
# 4                    81.635924
# 5                    80.467917
# 6                    80.693580
# 7                    82.003580
# 8                    80.687116
# 9                    79.248335
# 10                   79.894881
# 11                   81.452110
# 12                   79.944464
# 13                   82.501792
# 14                   80.422072
# 15                   80.707714
# 16                   81.056542
# 17                   78.523982
# 18                   85.984250
# 19                   81.806296
# 20                   78.837002
# 21                   78.383936
# 22                   82.501915
# 23                   78.580762
# 24                   81.251207
# 25                   83.064148
# 26                   80.500515
# 27                   83.731670
# 28                   80.450457
# 29                   79.690163
# 30                   79.546392
# 31                   85.082840

# %% [markdown]
# Since it is difficult to plot and read 5d figure for the above model. Hence, avoiding model plot.
